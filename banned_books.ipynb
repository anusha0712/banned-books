# %% [markdown]
# ## Exploring PEN America's School Book Bans Dataset

# %% [markdown]
# PEN America releases an annual list of book banning incidents in schools across the nation. Their indices are available for the three academic years starting from 2021 to 2024. The dataset includes data points for book titles, authors and series banned, geographical details and the date and authority of challenge. A book "challenge" is when someone like a parent, lawmaker or community member, complains about the book on the basis of its content and deems it unfit. In response to challenges, the book in question is investigated and taken off the shelf for the duration of the investigation. The result of the investigation will determine whether the book is returned to the shelf, banned in libraries, in classrooms or both.
#
# Banning books is often seen as an act of censorship meant to diminish intellectual freewill of citizens. While one side of it involves shielding young minds from 'inappropriate' or 'sexually explicit' content, the fact of the matter is that censorship often results in taboos, stigmas or shame being attached to certain topics in society. Additionally, as we move forward as a liberal and more inclusive society, the definition of what is 'inappropriate' or 'sexually explicit' remains in a state of flux. Topics exploring LGBTQ+ love or one's own sexuality or identity and difficult narratives on race are often blanketly deemed inappropriate and banned. Instead of stigmatizing them, real efforts should be made to encourage discussion and to debate the complex nuances of the realities that we live in, especially within the safety of our educational systems.
#
# This notebook is an exploration of the Index of banned books, attempting to parse out authors that have faced heavy censorship, states that lead in such challenges and any trends in the number and types of books being banned.
#
# Visuals were made using R (ggplot), Adobe Illustrator, Rawgraphs and Datawrapper.

# %%
import pandas as pd
import matplotlib as plt
import seaborn as sns

# %%
#load the individual files downloaded from PEN America to concatenate them

bb_2021 = pd.read_csv("data/bb_2021-2022.csv")

bb_2022 = pd.read_csv("data/bb_2022-2023.csv")
bb_2022.drop(columns = ["Series Name"], inplace = True)

bb_2023 = pd.read_csv("data/bb_2023-2024.csv")
bb_2023.drop(columns = ["Series Name"], inplace = True)

bb_2023.head()
# Out:
#                                             Title              Author  \
# 0                                     Next Summer      Abbott, Hailey
# 1                                    Summer Girls      Abbott, Hailey
# 2  In the Belly of the Beast: Letters From Prison  Abbott, Jack Henry
# 3                           The End of Everything       Abbott, Megan
# 4                         The Summer of Owen Todd        Abbott, Tony
#
#   Secondary Author(s) Illustrator(s) Translator(s)    State  \
# 0                 NaN            NaN           NaN  Florida
# 1                 NaN            NaN           NaN  Florida
# 2                 NaN            NaN           NaN  Florida
# 3                 NaN            NaN           NaN  Florida
# 4                 NaN            NaN           NaN  Florida
#
#                          District Date of Challenge/Removal  \
# 0  Escambia County Public Schools               August 2023
# 1  Escambia County Public Schools               August 2023
# 2    Orange County Public Schools                 June 2024
# 3              Lee County Schools                 June 2024
# 4  Escambia County Public Schools               August 2023
#
#                      Ban Status Origin of Challenge
# 0  Banned pending investigation      Administration
# 1  Banned pending investigation      Administration
# 2         Banned by restriction      Administration
# 3         Banned by restriction      Administration
# 4  Banned pending investigation      Administration

# %% [markdown]
# # Organizing Data

# %%
#I want a column for year but academic year is the most accurate. For books that don't have a certain date given, 
# it's hard to accurately put them in a single year bucket

bb_2021["Academic Year"] = ["2021-2022"] * len(bb_2021)
bb_2022["Academic Year"] = ["2022-2023"] * len(bb_2022)
bb_2023["Academic Year"] = ["2023-2024"] * len(bb_2023)

bb_2023.head()
# Out:
#                                             Title              Author  \
# 0                                     Next Summer      Abbott, Hailey
# 1                                    Summer Girls      Abbott, Hailey
# 2  In the Belly of the Beast: Letters From Prison  Abbott, Jack Henry
# 3                           The End of Everything       Abbott, Megan
# 4                         The Summer of Owen Todd        Abbott, Tony
#
#   Secondary Author(s) Illustrator(s) Translator(s)    State  \
# 0                 NaN            NaN           NaN  Florida
# 1                 NaN            NaN           NaN  Florida
# 2                 NaN            NaN           NaN  Florida
# 3                 NaN            NaN           NaN  Florida
# 4                 NaN            NaN           NaN  Florida
#
#                          District Date of Challenge/Removal  \
# 0  Escambia County Public Schools               August 2023
# 1  Escambia County Public Schools               August 2023
# 2    Orange County Public Schools                 June 2024
# 3              Lee County Schools                 June 2024
# 4  Escambia County Public Schools               August 2023
#
#                      Ban Status Origin of Challenge Academic Year
# 0  Banned pending investigation      Administration     2023-2024
# 1  Banned pending investigation      Administration     2023-2024
# 2         Banned by restriction      Administration     2023-2024
# 3         Banned by restriction      Administration     2023-2024
# 4  Banned pending investigation      Administration     2023-2024

# %%
# concatenating to create one big banned books df

banned_books_df = pd.concat([bb_2021, bb_2022, bb_2023], ignore_index=True)
banned_books_df.head()
# Out:
#                    Author               Title  \
# 0  Àbíké-Íyímídé, Faridah       Ace of Spades
# 1      Acevedo, Elizabeth  Clap When You Land
# 2      Acevedo, Elizabeth          The Poet X
# 3      Acevedo, Elizabeth          The Poet X
# 4      Acevedo, Elizabeth          The Poet X
#
#                            Ban Status Secondary Author(s) Illustrator(s)  \
# 0  Banned in Libraries and Classrooms                 NaN            NaN
# 1                Banned in Classrooms                 NaN            NaN
# 2                 Banned in Libraries                 NaN            NaN
# 3  Banned in Libraries and Classrooms                 NaN            NaN
# 4        Banned Pending Investigation                 NaN            NaN
#
#   Translator(s)         State                                    District  \
# 0           NaN       Florida         Indian River County School District
# 1           NaN  Pennsylvania                Central York School District
# 2           NaN       Florida         Indian River County School District
# 3           NaN      New York            Marlboro Central School District
# 4           NaN         Texas  Fredericksburg Independent School District
#
#   Date of Challenge/Removal Origin of Challenge Academic Year
# 0             November 2021       Administrator     2021-2022
# 1               August 2021       Administrator     2021-2022
# 2             November 2021       Administrator     2021-2022
# 3             February 2022       Administrator     2021-2022
# 4                March 2022       Administrator     2021-2022

# %%
#Check to make sure they combine to give the right number of rows
#len(bb_2021) + len(bb_2022) + len(bb_2023)

len(banned_books_df)
# Out:
# 15940

# %%
banned_books_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15940 entries, 0 to 15939
# Data columns (total 11 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Author                     15939 non-null  object
#  1   Title                      15939 non-null  object
#  2   Ban Status                 15940 non-null  object
#  3   Secondary Author(s)        794 non-null    object
#  4   Illustrator(s)             1307 non-null   object
#  5   Translator(s)              117 non-null    object
#  6   State                      15940 non-null  object
#  7   District                   15940 non-null  object
#  8   Date of Challenge/Removal  15940 non-null  object
#  9   Origin of Challenge        15940 non-null  object
#  10  Academic Year              15940 non-null  object
# dtypes: object(11)
# memory usage: 1.3+ MB

# %%
# which author and title values are missing?

banned_books_df[banned_books_df["Author"].isnull()]
# Out:
#      Author Title             Ban Status Secondary Author(s) Illustrator(s)  \
# 3130    NaN   NaN  Banned from Libraries                 NaN            NaN
#
#      Translator(s)  State                            District  \
# 3130           NaN  Texas  Frisco Independent School District
#
#      Date of Challenge/Removal Origin of Challenge Academic Year
# 3130              October 2022      Administration     2022-2023

# %%
# drop this, there is no way to find out what the book is 

banned_books_df = banned_books_df.dropna(subset=['Author', 'Title'])
banned_books_df.info()

# %%
banned_books_df["Ban Status"].value_counts()
# Out:
# Ban Status
# Banned Pending Investigation            7245
# Banned                                  4295
# Banned from Libraries and Classrooms    1596
# Banned by restriction                   1347
# Banned from Libraries                    940
# Banned from Classrooms                   516
# Name: count, dtype: int64

# %%
# normalising some parameters like Ban Status 

banned_books_df["Ban Status"] = banned_books_df["Ban Status"].replace({
    "Banned pending investigation": "Banned Pending Investigation",
    "Banned in Libraries": "Banned from Libraries",
    "Banned in Libraries and Classrooms": "Banned from Libraries and Classrooms",
    "Banned in Classrooms": "Banned from Classrooms"
})

# %%
#save this into a csv

banned_books_df.to_csv("data/all_banned_books.csv", index=False)

# %% [markdown]
# # Data Analysis

# %% [markdown]
# ### Each row is one instance of a ban. If 10 states ban the same book, it is counted as 10 bans of 1 unique title.
#
# Each row is better represented as a time a book was challenged and removed from shelfs. PEN america does not track whether they are ultimately returned to shelfs or not.
#
# This is counter to procedural best practices from the National Coalition Against Censorship (NCAC) and the American Library Association (ALA), which state that a book should remain in circulation while undergoing a reconsideration process.
#
# Banned by Restrictions mean that they seek to restrict it's access like parental permission or grade level

# %%
banned_books_df = pd.read_csv("data/all_banned_books.csv")
banned_books_df.head()
# Out:
#                    Author               Title  \
# 0  Àbíké-Íyímídé, Faridah       Ace of Spades
# 1      Acevedo, Elizabeth  Clap When You Land
# 2      Acevedo, Elizabeth          The Poet X
# 3      Acevedo, Elizabeth          The Poet X
# 4      Acevedo, Elizabeth          The Poet X
#
#                            Ban Status Secondary Author(s) Illustrator(s)  \
# 0  Banned in Libraries and Classrooms                 NaN            NaN
# 1                Banned in Classrooms                 NaN            NaN
# 2                 Banned in Libraries                 NaN            NaN
# 3  Banned in Libraries and Classrooms                 NaN            NaN
# 4        Banned Pending Investigation                 NaN            NaN
#
#   Translator(s)         State                                    District  \
# 0           NaN       Florida         Indian River County School District
# 1           NaN  Pennsylvania                Central York School District
# 2           NaN       Florida         Indian River County School District
# 3           NaN      New York            Marlboro Central School District
# 4           NaN         Texas  Fredericksburg Independent School District
#
#   Date of Challenge/Removal Origin of Challenge Academic Year
# 0             November 2021       Administrator     2021-2022
# 1               August 2021       Administrator     2021-2022
# 2             November 2021       Administrator     2021-2022
# 3             February 2022       Administrator     2021-2022
# 4                March 2022       Administrator     2021-2022

# %% [markdown]
# In the 2023-2024 academic year, there are 10,046 instances of book bans across USA (does not mean 10046 unique books were banned)

# %%
banned_books_df["Academic Year"].value_counts()
# Out:
# Academic Year
# 2023-2024    10046
# 2022-2023     3361
# 2021-2022     2532
# Name: count, dtype: int64

# %% [markdown]
# 6325 unique titles have been banned in USA from 2021-2024

# %%
# Number of unique titles banned in the US

len(banned_books_df["Title"].value_counts())
# Out:
# 6325

# %%
len(banned_books_df[banned_books_df["Academic Year"] == "2021-2022"]["Title"].value_counts())
# Out:
# 1648

# %%
# unique titles in 2022-2023
len(banned_books_df[banned_books_df["Academic Year"] == "2022-2023"]["Title"].value_counts())
# Out:
# 1556

# %%
# unique titles in 2023-2024

len(banned_books_df[banned_books_df["Academic Year"] == "2023-2024"]["Title"].value_counts())
# Out:
# 4240

# %%
list(banned_books_df[banned_books_df["Academic Year"] == "2021-2022"]["Title"].value_counts().reset_index()["Title"])
# Out:
# ['Gender Queer: A Memoir',
#  "All Boys Aren't Blue",
#  'Out of Darkness',
#  'The Bluest Eye',
#  'Lawn Boy',
#  'The Hate U Give',
#  'The Absolutely True Diary of a Part-Time Indian',
#  'Me and Earl and the Dying Girl',
#  'The Kite Runner',
#  'Crank (Crank Series)',
#  'Thirteen Reasons Why',
#  'l8r, g8r',
#  'Beloved',
#  'Drama: A Graphic Novel',
#  'Melissa (George)',
#  'Looking for Alaska',
#  'This Book Is Gay',
#  'Beyond Magenta: Transgender Teens Speak Out',
#  'This One Summer',
#  'Jack of Hearts (and other parts)',
#  'Flamer',
#  'All American Boys',
#  'Fun Home: A Family Tragicomic',
#  'The Breakaways',
#  "The Handmaid's Tale",
#  'Nineteen Minutes',
#  'The Perks of Being a Wallflower',
#  'Tricks (Tricks Series)',
#  'More Happy Than Not',
#  'Dear Martin',
#  'Extremely Loud & Incredibly Close',
#  'A Court of Mist and Fury (A Court of Thorns and Roses Series)',
#  'The 57 Bus: A True Story of Two Teenagers and the Crime That Changed Their Lives',
#  "It's Perfectly Normal: Changing Bodies, Growing Up, Sex, and Sexual Health",
#  "Monday's Not Coming",
#  'Sold',
#  'Almost Perfect',
#  'Speak',
#  "Real Live Boyfriends: Yes. Boyfriends, Plural. If My Life Weren't Complicated, I Wouldn't Be Ruby Oliver",
#  'Lucky',
#  'Being Jazz: My Life as a (Transgender) Teen',
#  'The Truth About Alice: A Novel',
#  'Eleanor & Park',
#  'The Glass Castle',
#  'And Tango Makes Three',
#  'Two Boys Kissing',
#  'Pride: The Story of Harvey Milk and the Rainbow Flag',
#  'We Are the Ants',
#  'Killing Mr. Griffin',
#  'I am Jazz',
#  'The Infinite Moment of Us',
#  'How to Be an Antiracist',
#  'Stamped: Racism, Antiracism, and You',
#  'They Called Themselves The K.K.K.: The Birth of an American Terrorist Group',
#  'Queer: The Ultimate LGBTQ Guide for Teens',
#  'Sloppy Firsts (Jessica Darling Series)',
#  'Fly on the Wall: How One Girl Saw Everything',
#  'Will Grayson, Will Grayson (Will Grayson, Will Grayson Series)',
#  'Trans Mission: My Quest to a Beard',
#  'Triangles',
#  'Forever...',
#  'I Am Not Your Perfect Mexican Daughter',
#  'Brave Face: A Memoir',
#  'Living Dead Girl',
#  'This Book Is Anti-Racist: 20 Lessons on How to Wake Up, Take Action, and Do the Work',
#  'The Music of What Happens',
#  'Cemetery Boys',
#  'Grasshopper Jungle (Grasshopper Jungle Series)',
#  'New Kid',
#  'Stamped from the Beginning: The Definitive History of Racist Ideas in America',
#  'Blended',
#  'Aristotle and Dante Discover the Secrets of the Universe (Aristotle and Dante Series)',
#  'City of Heavenly Fire (The Mortal Instruments Series)',
#  'Symptoms of Being Human',
#  'Homegoing',
#  'Ghost Boys',
#  "The Handmaid's Tale: The Graphic Novel",
#  'Lily and Dunkin',
#  'Gabi, a Girl in Pieces',
#  "In Our Mothers' House",
#  'The Poet X',
#  'grl2grl',
#  'The Baby Tree',
#  "Doing It!: Let's Talk About Sex",
#  'The Nowhere Girls',
#  'The Best Man',
#  'Separate Is Never Equal: Sylvia Mendez and Her Family’s Fight for Desegregation',
#  'Blankets',
#  'As I Descended',
#  "The Sin-Eater's Confession",
#  'Ask the Passengers',
#  "What If It's Us (What If It's Us Series)",
#  'The Moon Within',
#  'Black Girl Unlimited: The Remarkable Story of a Teenage Wizard',
#  'Of Fire and Stars (Of Fire and Stars Series)',
#  'If I Was Your Girl',
#  'The Upside of Unrequited (Simonverse Series)',
#  'The Haters',
#  'Class Act',
#  '33 Snowfish',
#  'Another Kind of Cowboy',
#  'Simon vs. the Homo Sapiens Agenda (Simonverse Series)',
#  'Geography Club (Russel Middlebrook Series)',
#  'Shine',
#  'Shout',
#  'An African American and Latinx History of the United States',
#  'The Past and Other Things That Should Stay Buried',
#  'Queer, There and Everywhere: 23 People Who Changed the World',
#  '#Hockey (Check, Please! Series)',
#  'Notes from the Blender',
#  'Afterworlds (Afterworlds Series)',
#  'Cinderella Is Dead',
#  'The New Jim Crow: Mass Incarceration in the Age of Colorblindness',
#  'Of Mice and Men',
#  'Not My Idea: A Book About Whiteness (Ordinary Terrible Things Series)',
#  'Ash',
#  'Juliet Takes a Breath',
#  "I'll Give You the Sun",
#  'The Black Flamingo',
#  'Milk and Honey',
#  'Everywhere Babies',
#  'The Magic Fish',
#  'The Nerdy and the Dirty',
#  'They Both Die at the End',
#  'The Family Fletcher Takes Rock Island (Family Fletcher Series)',
#  'A Court of Frost and Starlight (A Court of Thorns and Roses Series)',
#  'V for Vendetta',
#  'Hold Me Closer: The Tiny Cooper Story (Will Grayson, Will Grayson Series)',
#  'The Opposite of Innocent',
#  'What Girls Are Made Of',
#  'Darius the Great Deserves Better (Darius the Great Series)',
#  "Maus 1: A Survivor's Tale: My Father Bleeds History",
#  'Little & Lion',
#  'The Vincent Boys (The Vincent Boys Series)',
#  'Forever for a Year',
#  'Odd One Out',
#  'ttyl (Internet Girls Series)',
#  'Star-Crossed',
#  'Rainbow Revolutionaries: Fifty LGBTQ+ People Who Made History',
#  'The Miseducation of Cameron Post',
#  'Firestarter (Timekeeper Series)',
#  'Teens and Gender Dysphoria',
#  'History Is All You Left Me',
#  'Sex is a Funny Word: A Book about Bodies, Feelings, and YOU',
#  'Late to the Party',
#  'Infinity Son (Infinity Cycle Series)',
#  'The Migration North',
#  'To Night Owl from Dogfish',
#  'How to Love',
#  'Trans+: Love, Sex, Romance, and Being You',
#  'One of Those Hideous Books Where the Mother Dies',
#  'The Red Scrolls of Magic',
#  'Niño Wrestles the World (Niño Series)',
#  'The Stonewall Riots: Coming Out in the Street',
#  'Refugee',
#  'None of the Above',
#  'The Gravity of Us',
#  'Between the World and Me',
#  "As Far As You'll Take Me",
#  "Let's Talk About Love",
#  'Gingerbread (Cyd Charisse Series)',
#  'Gone, Gone, Gone',
#  'We Are Grateful: Otsaliheliga',
#  'Gender Identity: Beyond Pronouns and Bathrooms',
#  "SEX: If You're Scared of The Truth Don't Read This!",
#  'ttfn (Internet Girls Series)',
#  'Far from the Tree: How Children and Their Parents Learn to Accept One Another . . . Our Differences Unite Us',
#  'Wayward Witch (Brooklyn Brujas Series)',
#  'Not My Problem',
#  'Monster',
#  'Ordinary Hazards',
#  'Chicken Girl',
#  'Of Ice and Shadows (Of Fire and Stars Series)',
#  'Gracefully Grayson',
#  'Sister Mischief',
#  'Water for Elephants',
#  'The Last to Let Go',
#  'They, She, He Easy as ABC',
#  'Staying Fat for Sarah Byrnes',
#  'Islandborn',
#  'Pink Is for Boys',
#  'Sparkle Boy',
#  'Fancy White Trash',
#  'Her Royal Highness',
#  'Fallout (Crank Series)',
#  'Identical',
#  'Impulse (Impulse Series)',
#  'What We Saw',
#  'People Kill People',
#  'Perfect (Impulse Series)',
#  'Birthday',
#  'The Midnight Lie (Forgotten Gods Series)',
#  'Miles Away from You',
#  'Tilt',
#  'Traffick (Tricks Series)',
#  "I Hope You're Listening",
#  'The Abortion Debate (Essential Viewpoints)',
#  'My Heart Underwater',
#  'Dreaming in Cuban',
#  'Burned (Burned Series)',
#  'Roe v. Wade: The Untold Story of the Landmark Supreme Court Decision that Made Abortion Legal',
#  'Jasmine Toguchi, Flamingo Keeper (Jasmine Toguchi Series)',
#  'The Black Friend: On Being a Better White Person',
#  'A Quick & Easy Guide to Queer & Trans Identities',
#  'Tessa Masterson Will Go to Prom',
#  'Cradle and All',
#  'The Family Book',
#  'Unpregnant',
#  'Living Proud! Coming Out and Seeking Support (Living Proud! Growing Up Lgbtq)',
#  'The Great American Whatever',
#  'When We Were Magic',
#  'Doing It Right: Making Smart, Safe, and Satisfying Choices About Sex',
#  'In the Dream House',
#  'Jack',
#  'Normal People',
#  'Girl Crushed',
#  'A Love Story Starring My Dead Best Friend',
#  'Radiant Child: The Story of Young Artist Jean-Michel Basquiat',
#  'The Love Interest',
#  'We March',
#  'Stella Brings the Family',
#  'Panic',
#  'Girl Mans Up',
#  'Stained',
#  'Equal Rights',
#  'Sulwe',
#  'She Loves You, She Loves You Not...',
#  'Bad for You (Sea Breeze Series)',
#  'Gay Issues and Politics: Marriage, the Military, & Work Place Discrimination',
#  'The Stars and the Blackness Between Them',
#  'The Underground Girls of Kabul: in Search of a Hidden Resistance in Afghanistan',
#  "My Sister's Keeper",
#  'This Is My America',
#  'Far from You',
#  'The Parker Inheritance',
#  'Jesus Land: A Memoir',
#  'The Cider House Rules',
#  'It Gets Better: Coming Out, Overcoming Bullying, and Creating a Life Worth Living',
#  'No Girls Allowed: Tales of Daring Women Dressed as Men for Love, Freedom and Adventure',
#  'My Mixed-Up Berry Blue Summer',
#  'The Whispers',
#  'Totally Joe (The Misfits Series)',
#  "Drum Dream Girl: How One Girl's Courage Changed Music",
#  'Each of Us a Desert',
#  'Rainbow Boys (Rainbow Trilogy Series)',
#  'Perfect Chemistry (Perfect Chemistry Series)',
#  'Persepolis: The Story of a Childhood',
#  'After',
#  'Rick',
#  'Brave New World',
#  'Rage: A Love Story',
#  'So You Want to Talk About Race',
#  'Safe Sex 101: An Overview for Teens',
#  'The Last Exit to Normal',
#  'White Rabbit',
#  'Clockwork Princess (The Infernal Devices Series)',
#  'Indian No More',
#  'Dreadnought (H.I.V.E. Series)',
#  'Spinning',
#  "Ivy Aberdeen's Letter to the World",
#  'Girl Made of Stars',
#  'My Invented Life',
#  'Fade (Wake Series)',
#  'When the Moon Was Ours',
#  'To Kill a Mockingbird',
#  'Far from the Tree',
#  'Great',
#  'Death Wind',
#  'Lucky Broken Girl',
#  'Whistle Me Home',
#  'Gender Identity: The Search for Self',
#  'Slaughterhouse-Five',
#  'Vampire Academy (Vampire Academy Series)',
#  'Girl, (Nearly) 16: Absolute Torture',
#  'You Know Me Well',
#  'The Bridge',
#  'One Green Apple',
#  '7 Days at the Hot Corner',
#  'Who I Was with Her',
#  'Cut Both Ways',
#  "Marisol McDonald Doesn't Match (Marisol McDonald Series)",
#  'Black Rabbit Summer',
#  'Heavy: An American Memoir',
#  'This Is Your Time',
#  'Burn Baby Burn',
#  'Lubna and Pebble',
#  'All We Can Do Is Wait',
#  'And She Was',
#  'Follow Your Arrow',
#  'Highly Illogical Behavior',
#  'The Teenage Body Book',
#  'On the Come Up',
#  'Leah on the Offbeat (Simonverse Series)',
#  'Bioethics: Who Lives, Who Dies, And Who Decides?',
#  'The House You Pass on the Way',
#  'Ship It',
#  "Sonny's House of Spies",
#  'Sing a Song: How "Lift Every Voice and Sing" Inspired Generations',
#  'Front Desk (Front Desk Series)',
#  'Being the Change: Lessons and Strategies to Teach Social Comprehension',
#  'When Aidan Became A Brother',
#  'Love, Hate & Other Filters',
#  'A \u200bCourt of Silver Flames (A Court of Thorns and Roses Series)',
#  'How It All Blew Up',
#  'A Court of Thorns and Roses (A Court of Thorns and Roses Series)',
#  'Fry Bread: A Native American Family Story',
#  '10 Things I Can See from Here',
#  'Red at the Bone',
#  'Call Me Max (Max and Friends Series)',
#  'Night',
#  'Guardian (Proxy Series)',
#  'Masked',
#  'Last Night at the Telegraph Club',
#  'Morris Micklewhite and the Tangerine Dress',
#  'For Black Girls Like Me',
#  'Worm Loves Worm',
#  'The Testaments',
#  'Proxy (Proxy Series)',
#  'Daughters Unto Devils',
#  'Infandous',
#  'What They Always Tell Us',
#  'Alma and How She Got Her Name',
#  'Julián Is a Mermaid (Julián Series)',
#  'I Know Why The Caged Bird Sings',
#  'Encounter',
#  '#BlackLivesMatter: Protesting Racism',
#  "I'll Be the One",
#  'This Is Kind of an Epic Love Story',
#  "It's Not Like It's a Secret",
#  'My Most Excellent Year: A Novel of Love, Mary Poppins, and Fenway Park',
#  'Everybody Sees the Ants',
#  'Early Sunday Morning',
#  'Pride: Celebrating Diversity & Community',
#  'All the Things We Do in the Dark',
#  'Echo After Echo',
#  'The Love Curse of Melody McIntyre',
#  'Felix Ever After',
#  'The Gender Quest Workbook: A Guide for Teens and Young Adults Exploring Gender Identity',
#  'Graceling (Graceling Realm Series)',
#  'Dreamers',
#  'Everything You Love Will Burn: Inside the Rebirth of White Nationalism in America',
#  'Boy Girl Boy',
#  'Openly Straight (Openly Straight Series)',
#  'Jane, Unlimited',
#  'The Name Jar',
#  'Your Rights as an LGBTQ+ Teen',
#  'Wings of Shadow (Crown of Feathers Series)',
#  "Don't Touch My Hair!",
#  "Uncle Jed's Barber Shop",
#  'Sisters/Hermanas',
#  'Friendship, Dating, and Relationships (Teens: Being Gay, Lesbian, Bisexual, or Transgender)',
#  'Proud: Living My American Dream (Young Readers Edition)',
#  'Between Us and Abuela: A Family Story from the Border',
#  'This Day in June',
#  'Up, Up, Down!',
#  'Transgender Rights and Issues',
#  'Tomorrow Will Be Different: Love, Loss, and the Fight for Trans Equality',
#  'Gideon the Ninth (The Locked Tomb Series)',
#  'Heart of Flames (Crown of Feathers Series)',
#  'All Are Welcome',
#  'Blood Sport',
#  'GLBT Teens and Society',
#  'Ramona Blue',
#  'Crown of Feathers (Crown of Feathers Series)',
#  'Protect and Defend (Kerry Kilcannon Series)',
#  'Homophobia: From Social Stigma to Hate Crimes',
#  'Every Heart a Doorway (Seanan McGuire Series)',
#  'Dope Sick',
#  'Heroine',
#  'The Best at It',
#  'Come with Me',
#  'Synchro Boy',
#  'Bloom',
#  'Wings',
#  'What Was the Underground Railroad? (What was...? Series)',
#  'Hands Up!',
#  'M or F?',
#  'Zen Shorts (Zen Series)',
#  'Culturally Sustaining Pedagogies: Teaching and Learning for Justice in a Changing World',
#  "Nya's Long Walk: A Step at a Time",
#  'How Prevalent Is Racism in Society?',
#  'Swimming with Faith: The Missy Franklin Story (ZonderKidz Biography Series)',
#  'Teenage Sex and Pregnancy',
#  'The Black Lives Matter Movement',
#  "Esta bien ser diferente/It's Okay to Be Different (Spanish Version)",
#  'Blood Water Paint',
#  'Indestructible Object',
#  'Jaya and Rasa: A Love Story',
#  'Bridge to Terabithia',
#  'Cultivating Genius: An Equity Framework for Culturally and Historically Responsive Literacy',
#  'How Beautiful We Were',
#  'Here the Whole Time',
#  'Did I Mention I Need You? (DIMILY Series)',
#  'The Field Guide to the North American Teenager',
#  "The ABC's of LGBT+",
#  'No Ashes in the Fire: Coming of Age Black and Free in America',
#  'Teens & Sex',
#  'Discovering Wes Moore',
#  'My Life as a Diamond',
#  'Peeny Butter Fudge',
#  'The Tenth Circle',
#  'Saturday',
#  'Mastiff (Beka Cooper Series)',
#  'Thank You, Omu!',
#  'Pushout: The Criminalization of Black Girls in Schools',
#  'The Will of the Empress (The Circle Reforged Series)',
#  'It Goes Like This',
#  'Love to Mama: A Tribute To Mothers',
#  'Encyclopedia of Sex & Gender: 4 Volume Set',
#  'Strange Fruit: Why Both Sides Are Wrong in the Race Debate',
#  'A Curse of Roses',
#  'Identity: A Story of Transitioning',
#  'Duke Ellington: The Piano Prince and His Orchestra',
#  'Fishing Day',
#  'The Sunday Outing',
#  "It Doesn't Have to Be Awkward: Dealing with Relationships, Consent, and Other Hard-to-Talk-About Stuff",
#  'When Angels Sing: The Story of Rock Legend Carlos Santana',
#  'Unravel Me (Shatter Me Series)',
#  'Our Skin: A First Conversation About Race',
#  'Sometime After Midnight',
#  'Losing the Girl: Book 1 (Life on Earth)',
#  'Hey Black Child',
#  'The Guide for White Women Who Teach Black Boys',
#  'Skin Like Mine (Kids Like Mine Series)',
#  'Between Mom and Jo',
#  'Barbed Wire Baseball: How One Man Brought Hope to the Japanese Internment Camps of WWII',
#  'Far from Xanadu',
#  'The Rough-Face Girl',
#  'Boy-Crazy Stacey (The Baby-Sitters Club Series)',
#  '47',
#  'Out Now: Queer We Go Again!',
#  'Marco Impossible',
#  'Knots on a Counting Rope',
#  'The Girls Are Never Gone',
#  "It's Our Prom (So Deal With It)",
#  'Keeping You a Secret',
#  'Baseball Saved Us',
#  'The Gold-Threaded Dress',
#  'Lies My Girlfriend Told Me',
#  'The Drinking Gourd: A Story of the Underground Railroad',
#  'The Girl with a Mind for Math: The Story of Raye Montague',
#  'No One Knows About You',
#  'Squeak, Rumble, Whomp! Whomp! Whomp!: A Sonic Adventure',
#  'Blue Is the Warmest Color',
#  'The Doctor with an Eye for Eyes: The Story of Dr. Patricia Bath',
#  'Should Abortion Be Legal?',
#  'Get Up, Stand Up',
#  'Gender Identity (Teen Mental Health)',
#  'Black Software: The Internet & Racial Justice, from the Afronet to Black Lives Matter',
#  'White Bird',
#  'Gender Issues (Living with a Special Need)',
#  'Princess Princess Ever After',
#  'The Trouble with Black Boys: And Other Reflections on Race, Equity, and the Future of Public Education',
#  'Thunder Rose',
#  'Sex & Violence',
#  'Perfectly Good White Boy',
#  'Always Human (Always Human Series)',
#  'Neanderthal Opens the Door to the Universe',
#  'yolo (Internet Girls Series)',
#  'Meg & Linus',
#  'Good Trouble: Lessons from the Civil Rights Playbook',
#  'Victor and Nora: A Gotham Love Story',
#  'Night of the Zombie Zookeeper (Desmond Cole Ghost Patrol Series)',
#  '¿De Dónde Eres?/Where Are You From?',
#  'Becoming Nicole: The inspiring story of transgender actor-activist Nicole Maines and her extraordinary family',
#  'The Flag of Childhood: Poems From the Middle East',
#  'A Kids Book About Racism',
#  "Chasing Space Young Readers' Edition",
#  'The Turtle of Oman (The Turtle of Oman Series)',
#  'I Am Rosa Parks',
#  'The Things They Carried',
#  'I am Martin Luther King, Jr.',
#  'All Our Hidden Gifts (All Our Hidden Gifts Series)',
#  'In the Role of Brie Hutchens...',
#  'We Set the Dark on Fire (We Set the Dark on Fire Series)',
#  'A Family Is a Family Is a Family',
#  'I Am Alfonso Jones',
#  "Fairest: Levana's Story (The Lunar Chronicles Series)",
#  'Breathless',
#  'Eclipse (Twilight Series)',
#  'Beware the Werewolf (Desmond Cole Ghost Patrol Series)',
#  'Yang the Third and Her Impossible Family (The Yang Family Series)',
#  'A is for Activist',
#  'Major Monster Mess (Desmond Cole Ghost Patrol Series)',
#  'Ghouls Just Want to Have Fun (Desmond Cole Ghost Patrol Series)',
#  "Ghosts Don't Ride Bikes, Do They? (Desmond Cole Ghost Patrol Series)",
#  'Yang the Youngest and his Terrible Ear (The Yang Family Series)',
#  'Escape from the Roller Ghoster (Desmond Cole Ghost Patrol Series)',
#  'Should Teens Have Access to Birth Control?',
#  'Campfire Stories (Desmond Cole Ghost Patrol Series)',
#  'Understanding Gender Identity',
#  'Reluctantly Alice (Alice Series)',
#  'Nelson Mandela',
#  'October Mourning: A Song for Matthew Shepard',
#  "The Book Itch: Freedom, Truth & Harlem's Greatest Bookstore",
#  'I Am Who I Am',
#  'Planet Omar: Unexpected Super Spy (Planet Omar Series)',
#  'Planet Omar: Incredible Rescue Mission (Planet Omar Series)',
#  'Planet Omar: Epic Hero Flop (Planet Omar Series)',
#  'Daddy, Papa, and Me',
#  'Heather Has Two Mommies',
#  'Planet Omar: Accidental Trouble Magnet (Planet Omar Series)',
#  'Jailbait',
#  'Mommy, Mama, and Me',
#  'Lolita',
#  'Under the Moon: A Catwoman Tale',
#  'Asking for It',
#  'Lulu and the Duck in the Park (Lulu Series)',
#  'Identity and Gender',
#  'Away We Go',
#  'When the Emperor Was Divine',
#  'Lola Loves Stories (Lola Series)',
#  'Lola Goes to School (Lola Series)',
#  'Who Wants I Scream? (Desmond Cole Ghost Patrol Series)',
#  'Lola Gets a Cat (Lola Series)',
#  'The Imitation Game: Alan Turing Decoded',
#  'Kissing Kate',
#  'These Feathered Flames (These Feathered Flames Series)',
#  'The Life and (Medieval) Times of Kit Sweetly',
#  'Lola at the Library with Mommy (Lola Series)',
#  "The Witch's Hand (The Montague Twins)",
#  'Touching Spirit Bear (Spirit Bear Series)',
#  'Lola at the Library (Lola Series)',
#  '#MurderTrending (MurderTrending Series)',
#  'Nonbinary Gender Identities: History, Culture, Resources',
#  'Gearbreakers (Gearbreakers Series)',
#  'Brave Leaders and Activists',
#  'How to Be Bad',
#  'Dark and Deepest Red',
#  'Blanca & Roja',
#  'On the Other Side of Freedom: The Case for Hope',
#  'Dear Juno',
#  'Are You LGBTQ?',
#  'What We Devour',
#  'Lola Loves Stories with Daddy (Lola Series)',
#  'Lola Plants a Garden (Lola Series)',
#  'The Vampire Ate My Homework (Desmond Cole Ghost Patrol Series)',
#  'The Scary Library Shusher (Desmond Cole Ghost Patrol Series)',
#  'Before I Fall',
#  'Who Was Aretha Franklin? (Who was...? Series)',
#  'What Was Stonewall? (What was...? Series)',
#  'Broken Things',
#  'Our Class is a Family',
#  'Yaqui Delgado Wants to Kick Your Ass',
#  'Mango, Abuela, and Me',
#  'Juana & Lucas (Juana and Lucas Series)',
#  "Now Museum, Now You Don't (Desmond Cole Ghost Patrol Series)",
#  "Surf's Up, Creepy Stuff! (Desmond Cole Ghost Patrol Series)",
#  'The Haunted House Next Door (Desmond Cole Ghost Patrol Series)',
#  'Stay Gold',
#  'The Witch Boy (The Witch Boy Series)',
#  'Act Cool',
#  'The People Shall Continue',
#  'Heartstopper: Volume One (Heartstopper Series)',
#  'Little Night/Nochecita',
#  'Heartstopper: Volume Three (Heartstopper Series)',
#  'Heartstopper: Volume Two (Heartstopper Series)',
#  'The Sleepwalking Snowman (Desmond Cole Ghost Patrol Series)',
#  'Anger Is a Gift',
#  'Lola Sleeps Over (Lola Series)',
#  'Anger Is a Gift: A Novel',
#  'Lola Reads to Leo (Lola Series)',
#  'The Proudest Blue: A Story of Hijab and Family',
#  'Ace of Spades',
#  'The Bell Jar',
#  'As Fast as Words Could Fly',
#  'Abortion (Opposing Viewpoints Series)',
#  'The Princess and the Warrior: A Tale of Two Volcanoes',
#  'Soldier for Equality: José de la Luz Sáenz and the Great War',
#  "Grandfather Tang's Story",
#  'Squad',
#  'Remake (Remake Series)',
#  'After We Collided (After Series)',
#  'My Whole Truth',
#  'Tarnished Are the Stars',
#  'Keena Ford and the Second Grade Mix Up (Keena Ford Series)',
#  'Who Was Eleanor Roosevelt? (Who was...? Series)',
#  'Your Name Is a Song',
#  'From the Stars in the Sky to the Fish in the Sea',
#  'High Drama (Suspended Series)',
#  'Meg, Jo, Beth, and Amy: A Modern Graphic Retelling of Little Women',
#  'The Hiding Place: The Triumphant True Story of Corrie Ten Boom',
#  'Me Myself & Him',
#  'Sally and The Magical Sneeze',
#  "Henry Aaron's Dream",
#  'Fan Art',
#  'Hachiko: The True Story of a Loyal Dog',
#  'What Happened to Lani Garver',
#  'A Day in the Life of Marlon Bundo',
#  "Faith Ringgold (Getting to Know the World's Greatest Artists)",
#  'Kiss Number 8',
#  'Looking for Bongo',
#  'Y: The Last Man',
#  'Saga, Volume 1 (Saga Series)',
#  "Iron Heart (Crier's War Series)",
#  "Crier's War (Crier's War Series)",
#  'Alison, Who Went Away',
#  'Totem Tale',
#  'Date Me, Bryson Keller',
#  'Peanut Goes for the Gold',
#  'Subtractive Schooling: U.S.-Mexican Youth and the Politics of Caring',
#  'Hello Now',
#  'Beyond the Gender Binary',
#  'Sticks & Scones (Check, Please! Series)',
#  'Dad, Jackie, and Me',
#  'A Storm Called Katrina',
#  'The Bracelet',
#  'The Skin You Live In',
#  'Why Are All the Black Kids Sitting Together in the Cafeteria?: And Other Conversations About Race',
#  'Can We Talk about Race?: And Other Conversations in an Era of School Resegregation',
#  'The Last Confession of Autumn Casterly',
#  'Golden Boy',
#  'En el bosque',
#  'Big Guy',
#  'The Fire Never Goes Out: A Memoir in Pictures',
#  'Promoting Racial Literacy in Schools: Differences That Make a Difference',
#  "The Exact Opposite of Okay (Izzy O'Neill Series)",
#  "These Witches Don't Burn (These Witches Don't Burn Series)",
#  'The Coldest Touch',
#  'The Art of Racing in the Rain',
#  "The Watcher's Test (Deadendia Series)",
#  'Whistling Vivaldi: And Other Clues to How Stereotypes Affect Us',
#  'The List of Things That Will Not Change',
#  'Deogratias: A Tale of Rwanda',
#  'Bright World (The Hazards of Love Series)',
#  '25 Women Who Ruled',
#  'The Gravity of Us (The Gravity of Us Series)',
#  'Freak Show',
#  "Maus II: A Survivor's Tale: And Here My Troubles Began",
#  'I Am Water',
#  'Go Ask Alice',
#  'Under Threat',
#  'Who Is Michelle Obama? (Who was...? Series)',
#  'Who Is Sonia Sotomayor? (Who was...? Series)',
#  'Shining Legacy: A Treasury of "Storypoems and Tales for the Young So Black Heroes Forever Will Be Sung"',
#  'I Love My Hair',
#  'Cilla Lee-Jenkins: This Book Is a Classic (Cilla Lee-Jenkins Series)',
#  'Cilla Lee-Jenkins: The Epic Story (Cilla Lee-Jenkins Series)',
#  'Cilla Lee-Jenkins: Future Author Extraordinaire (Cilla Lee-Jenkins Series)',
#  'Laura Dean Keeps Breaking Up with Me',
#  'Pulp',
#  'Music from Another World',
#  'They Called Us Enemy',
#  "Big Hair, Don't Care",
#  'Who Was Marie Curie? (Who was...? Series)',
#  'Forbidden',
#  'The Dangerous Art of Blending In',
#  'Mommy Sayang: Pixar Animation Studios Artist Showcase',
#  'The Confessions of Nat Turner',
#  'Born Out of Struggle: Critical Race Theory, School Creation, and the Politics of Interruption',
#  'A Bad Boy Can Be Good for a Girl',
#  'Clean Getaway',
#  'Between Perfect and Real',
#  'I Am Human: A Book of Empathy (I Am... Series)',
#  'This Golden Flame',
#  'Fifteen Hundred Miles from the Sun',
#  'The Boy in the Dress',
#  'El Día En Que Descubres Quién Eres',
#  'Each Kindness',
#  'Brown Girl Dreaming',
#  'Beneath a Meth Moon: An Elegy',
#  'Before the Ever After',
#  'Identifying as Transgender',
#  'My Name Is Sally Little Song',
#  'Saturdays with Hitchcock',
#  'Parrotfish',
#  'The Summer of Everything',
#  'Sonia Sotomayor: A Judge Grows in the Bronx/La juez que creció en el Bronx',
#  'Roberto Clemente: Pride of the Pittsburgh Pirates',
#  'Gender Identity: The Ultimate Teen Guide',
#  'No Way, They Were Gay?: Hidden Lives and Secret Loves',
#  'We Now Return to Regular Life',
#  'What Is Black Lives Matter? (What was...? Series)',
#  'Young Gifted and Black: Meet 52 Black Heroes from Past and Present',
#  'Fences',
#  'The Art of Being Normal',
#  'The Day You Begin',
#  'The Dear One',
#  'The Other Side',
#  'One Hot Second: Stories About Desire',
#  'Black Enough: Stories of Being Young & Black in America',
#  'American Street',
#  'Read the World: Rethinking Literacy for Empathy and Action in a Digital Age',
#  'The Garden of My Imaan',
#  'Who Was Sojourner Truth? (Who was...? Series)',
#  'Witchlight',
#  "Malala's Magic Pencil",
#  "Malala: My Story of Standing Up for Girls' Rights",
#  'Coolies',
#  'Understanding Sexuality',
#  'Dragonwings',
#  'Parachutes',
#  'American Born Chinese',
#  'Orphea Proud',
#  'Always my Dad',
#  'Putting Makeup on the Fat Boy',
#  'Noah Chases the Wind',
#  'Life at School and in the Community (Teens: Being Gay, Lesbian, Bisexual, or Transgender)',
#  'Four Feet, Two Sandals',
#  "Daddy's Roommate",
#  'The Grief Keeper',
#  'Because',
#  'The Shape of Thunder',
#  'Other Words for Home',
#  'Aesop Lake',
#  'Salvage the Bones (Bois Sauvage Series)',
#  'The Prince and the Dressmaker',
#  'Empty',
#  'Introducing Teddy',
#  'If We Were Us',
#  'Grace Hopper: Queen of Computer Code',
#  'Ada Byron Lovelace and the Thinking Machine',
#  'Dishes',
#  'The Color Purple',
#  'Our Favorite African Adrinkra Symbols: A Coloring Book',
#  'Beyond Theory: A Blueprint to Implement African-Centered Education',
#  'On a Sunbeam (On a Sunbeam Series)',
#  'Condoleezza Rice: Being the Best (Gateway Biographies)',
#  'Gossip Girl: A Novel by Cecily von Ziegesar (Gossip Girl Series)',
#  'Crossing Lines',
#  'Black and White',
#  'Ghost Wood Song',
#  "Harlem's Little Blackbird: The Story of Florence Mills",
#  'Piecing Me Together',
#  'Molly of Denali: Berry Itchy Day',
#  'Pink',
#  'Caste: The Origins of Our Discontents',
#  'Playing a Part',
#  'Lights, Music, Code! (Girls Who Code Series)',
#  'Considering Hate: Violence, Goodness, and Justice in American Culture and Politics',
#  'The Dark Descent of Elizabeth Frankenstein',
#  "And I Darken (The Conqueror's Saga Series)",
#  'A Certain Slant of Light',
#  'On the Come Up: A Novel, Based on a True Story',
#  'Before John Was a Jazz Giant: A Song of John Coltrane',
#  'Uglies (Uglies Series)',
#  'Saving Ruby King',
#  'Yoko (Yoko Series)',
#  'Luciana (Nine Months Series)',
#  'The Book of Essie',
#  'Suicide Notes From Beautiful Girls',
#  'Gordon Parks: How the Photographer Captured Black and White America',
#  'Freedom in Congo Square',
#  'Beast',
#  'We Used to Be Friends',
#  'The Summer of Jordi Perez (And the Best Burger in Los Angeles)',
#  'The Tyrant’s Tomb (The Trials of Apollo Series)',
#  'Lost Boys',
#  'Girls vs. Guys: Surprising Differences Between the Sexes',
#  'Abortion: A Documentary and Reference Guide',
#  'Satanism (At Issue)',
#  'The Fell of Dark',
#  'Death Prefers Blondes',
#  'Lucy Peale',
#  'Living with Religion and Faith',
#  'Finding Community',
#  'Hey, Charleston!: The True Story of the Jenkins Orphanage Band',
#  'Chik Chak Shabbat',
#  'Where We Go From Here',
#  'Girls at the Edge of the World',
#  'The Hero Two Doors Down: Based on the True Story of Friendship between a Boy and a Baseball Legend',
#  'Were I Not a Girl: The Inspiring and True Story of Dr. James Barry',
#  'You Matter',
#  'Another',
#  'Hiawatha and the Peacemaker',
#  'The Barren Grounds (The Misewa Saga Series)',
#  'Cherry',
#  'Shades of People',
#  'House of Furies (House of Furies Series)',
#  'She/He/They/Me: For the Sisters, Misters, and Binary Resisters',
#  'Hold Back the Tide',
#  'The Story of Rap',
#  'The Inexplicable Logic of My Life',
#  'Aristotle and Dante Dive into the Waters of the World (Aristotle and Dante Series)',
#  'Bilal Cooks Daal',
#  'Amal Unbound',
#  'Elizabeth Blackwell, the First Woman Doctor',
#  'Me and White Supremacy: Combat Racism, Change the World, and Become a Good Ancestor',
#  'When You Get the Chance',
#  'Any Way the Wind Blows (Simon Snow Series)',
#  'Empress of the World (Battle Hall Davies Series)',
#  'Esperanza Rising',
#  'Saints of Augustine',
#  'Little Melba and Her Big Trombone',
#  'My Awesome/Awful Popularity Plan (Justin Goldblatt Series)',
#  'The God of Small Things',
#  'Wayward Son (Simon Snow Series)',
#  'Carry On (Simon Snow Series)',
#  'Two Dads: A Book About Adopton',
#  'The Hidden Oracle (The Trials of Apollo Series)',
#  '642 Things to Write About',
#  'The Hammer of Thor (Magnus Chase and the Gods of Asgard Series)',
#  "My Mother's Sari",
#  'Citizen: An American Lyric',
#  'The Truth Is',
#  'A Good Kind of Trouble',
#  'Scars',
#  "Ready or Not?: A Girl's Guide to Making Her Own Decisions about Dating, Love, and Sex",
#  "Bend, Don't Shatter: Poets on the Beginning of Desire",
#  'My Papi Has a Motorcycle',
#  'Tomboy: A Graphic Memoir',
#  'Burn Our Bodies Down',
#  'Baby & Solo',
#  'The Blood Countess (Lady Slayers Series)',
#  'The City Beautiful',
#  'Everyday Antiracism: Getting Real About Race in School',
#  'Who Was Susan B. Anthony? (Who was...? Series)',
#  'Who Was Lucille Ball? (Who was...? Series)',
#  'The Butterfly',
#  'Mrs. Katz and Tush',
#  'Like Water',
#  "Wilma's Way Home: The Life of Wilma Mankiller",
#  'We the Students: Supreme Court Cases for and about Students',
#  'Dumpling Soup',
#  'Beyond Dreams (Hamilton High Series)',
#  'The Dark Prophecy (The Trials of Apollo Series)',
#  'The Burning Maze (The Trials of Apollo Series)',
#  'Pink!',
#  'Ninth Ward (The Louisiana Girls Trilogy Series)',
#  'Bayou Magic (The Louisiana Girls Trilogy Series)',
#  'Three Little Words: A Memoir',
#  'Say Something',
#  'Detour for Emmy',
#  'Patina (Track Series)',
#  'Who Is the Dalai Lama? (Who was...? Series)',
#  'Look Both Ways: A Tale Told in Ten Blocks',
#  'Ghost (Track Series)',
#  'As Brave As You',
#  "On the Bright Side, I'm Now the Girlfriend of a Sex God (Confessions of Georgia Nicolson #2)",
#  'The Black Kids',
#  'Beautiful',
#  'Who Was Harriet Beecher Stowe? (Who was...? Series)',
#  'Who Was Cesar Chavez? (Who was...? Series)',
#  "Can't Take That Away",
#  'Bait',
#  'The Summer of Jordi Perez',
#  'Ven a Mi Casa',
#  'Gender Danger: Survivors of Rape, Human Trafficking, and Honor Killings',
#  'Chainbreaker (Timekeeper Series)',
#  'Jack (Not Jackie)',
#  'Infinity Reaper (Infinity Cycle Series)',
#  'Somebody Told Me',
#  "Tameka's New Dress",
#  'Nelson Beats The Odds',
#  'Edie in Between',
#  'Game Changer',
#  'Hidden Figures: The True Story of Four Black Women and the Space Race',
#  'Final Takedown',
#  '25 Women Who Thought of It First',
#  '25 Women Who Fought Back',
#  'Influence',
#  'Flawless (Pretty Little Liars Series)',
#  'The Hookup Artist',
#  'Safe',
#  "The Girls I've Been",
#  'The Berlin Boxing Club',
#  'Marriage of a Thousand Lies',
#  'Courageous Conversations About Race: A Field Guide for Achieving Equity in Schools and Beyond',
#  'Bonds of Brass',
#  'The Deep & Dark Blue',
#  '¡Solo pregunta!: Sé Diferente, Sé Valiente, Sé Tú',
#  'Too Many Tamales',
#  "At the Mountain's Base",
#  "What My Mother Doesn't Know (What My Mother Doesn't Know Series)",
#  'Far From the Tree: Parents, Children and the Search for Identity',
#  'How We Fight White Supremacy',
#  'The Boy of the Three-Year Nap',
#  'The Falling in Love Montage',
#  "Invisible Man, Got the Whole World Watching: A Young Black Man's Education",
#  'The Edge of the Abyss (The Abyss Surrounds Us Series)',
#  'Stick',
#  'The Way I Used to Be',
#  'Something Like Gravity',
#  'Tonight We Rule the World',
#  'Deposing Nathan',
#  'Transformative Ethnic Studies in Schools: Curriculum, Pedagogy, and Research',
#  'Exquisite: The Poetry and Life of Gwendolyn Brooks',
#  "Climbing Lincoln's Steps: The African American Journey",
#  "My Girlfriend's Pregnant!: A Teen’s Guide to Becoming a Dad",
#  'Out of the Easy',
#  'Getting It',
#  'Between Shades of Gray',
#  'Get a Clue (Bookish Boyfriends Series)',
#  'Lizard Radio',
#  'Black Frontiers: A History of African American Heroes in the Old West',
#  'The Questions Within (Cutting Edge Series)',
#  'Fans of the Impossible Life',
#  'All the World',
#  'Ana on the Edge',
#  'Push',
#  "I'm A Gay Wizard",
#  'Just Ash',
#  'Gay Believers: Homosexuality and Religion',
#  "Something Must Be Wrong with Me: A Boy's Book about Sexual Abuse",
#  'Stonewall: A Building. An Uprising. A Revolution.',
#  'Peaceful Fights for Equal Rights',
#  'The (Un)Popular Vote',
#  'You Brought Me the Ocean',
#  'So Hard to Say',
#  'Rainbow Road (Rainbow Trilogy Series)',
#  'Rainbow High (Rainbow Trilogy Series)',
#  'The Last Time I Wore a Dress',
#  'The Darkness Outside Us',
#  'Spotlight on Coding Club! (Girls Who Code Series)',
#  'Gays and Mental Health: Fighting Depression, Saying No to Suicide',
#  'Just Kill Me',
#  'A Very, Very Bad Thing',
#  'Festival of Colors',
#  'The Deaf Musicians',
#  'The Lovely Bones',
#  'Ember Queen (Ash Princess Trilogy Series)',
#  'The LGBT Community',
#  'Homosexuality Around the World: Safe Havens, Cultural Challenges',
#  'Gay People of Color: Facing Prejudices, Forging Identities',
#  'The Invisible Life of Addie LaRue',
#  'Gay and Lesbian Role Models',
#  'Feeling Wrong in Your Own Body: Understanding What It Means to Be Transgender',
#  'Coming Out: Telling Family and Friends',
#  "On Mother's Lap",
#  'SELF-ish: A Transgender Awakening',
#  'Locked Up for Freedom: Civil Rights Protesters at the Leesburg Stockade',
#  'Scary Stories to Tell in the Dark',
#  'The Hope Chest',
#  'It Began with a Page: How Gyo Fujikawa Drew the Way',
#  "The Ultimate Guys' Body Book: Not-So-Stupid Questions About Your Body",
#  'And Still the Turtle Watched',
#  'The Mighty Miss Malone',
#  'LGBT Families (Changing Families)',
#  'Whale Talk',
#  'Striving for Equality: LGBTQ Athletes Claim the Field',
#  'Beautiful Music for Ugly Children',
#  'Rift (Nightshade Prequel Series)',
#  'Walk Two Moons',
#  "A Guy's Guide to Sexuality and Sexual Identity in the 21st Century",
#  'My Family Plays Music',
#  'Unstoppable: How Jim Thorpe and the Carlisle Indian School Football Team Defeated Army (Encounter: Narrative Nonfiction Picture Books Series)',
#  'The Sky Blues',
#  'A Dream Come True: Coming to America from Vietnam-1975',
#  'Jabari Jumps (Jabari Series)',
#  'Wait, What?: A Comic Book Guide to Relationships, Bodies, and Growing Up',
#  'S.E.X.: The All-You-Need-To-Know Progressive Sexuality Guide to Get You Through High School and College',
#  'Malala: A Hero for All (Step into Reading Series)',
#  'Labyrinth Lost (Brooklyn Brujas Series)',
#  'Bruja Born (Brooklyn Brujas Series)',
#  'Max and the Tag-Along Moon',
#  'Full, Full, Full of Love',
#  'A Peacock Among Pigeons',
#  'A Case of Sense',
#  'Revealed (House of Night Series)',
#  'Dreadnought (Nemesis Series)',
#  'The Friendship Code (Girls Who Code Series)',
#  'Team BFF: Race to the Finish! (Girls Who Code Series)',
#  'I Think I Love You',
#  'Gender Equality (Foundations of Democracy)',
#  'Cece Loves Science (Cece Loves Science Series)',
#  'The Legend of the Bluebonnet (Legends Series)',
#  'Teaching When the World Is on Fire',
#  '"Multiplication Is for White People": Raising Expectations for Other People\'s Children',
#  '14 Cows for America',
#  'Maybe He Just Likes You',
#  'I Wish You All the Best (I Wish You All the Best Series)',
#  'The Gods of Tango',
#  'Mexican Whiteboy',
#  'Last Stop on Market Street',
#  'Carmela Full of Wishes',
#  "I'm a Wild Seed: My Graphic Memoir on Queerness and Decolonizing the World",
#  'The Boy I Love',
#  'Understanding Gender',
#  'Happy families',
#  'Short Stuff: A Young Adult LGBTQ+ Anthology',
#  'The Life of Rosa Parks (Famous Lives Series)',
#  'A Home for Goddesses and Dogs',
#  'Boy Erased: A Memoir of Identity, Faith, and Family',
#  'The Lost Book of the White (The Eldest Curses Series)',
#  'The House on Mango Street',
#  'Brave (Berrybrook Middle School Series)',
#  'Sam and the Lucky Money',
#  'Amelia to Zora: Twenty-Six Women Who Changed the World',
#  'The Bride Was a Boy',
#  'Brother Eagle, Sister Sky',
#  'Hair Love',
#  'The Year of the Book (Anna Wang Series)',
#  'Etched in Clay: The Life of Dave, Enslaved Potter and Poet',
#  'Rebel Girl Revolution (Fat Angie Series)',
#  'Homecoming (Fat Angie Series)',
#  'Fat Angie (Fat Angie Series)',
#  'The Rape of Nanking',
#  'Celia Cruz, Queen of Salsa',
#  'Gaby, Lost and Found',
#  'Something Happened in Our Town',
#  'Celebrating Different Beliefs',
#  'Untamed (House of Night Series)',
#  'The Red Scrolls of Magic (The Eldest Curses Series)',
#  'Let the Children March',
#  'Freakboy',
#  'Thank You, Jackie Robinson',
#  'All the Invisible Things',
#  'The Traitor Game',
#  'The Story of Ruby Bridges',
#  "Things We Couldn't Say",
#  ...]

# %%
# did some books get unbanned cause number goes down from 2021 to 2022? Do banned books remain banned forever?


unique_2021 = list(banned_books_df[banned_books_df["Academic Year"] == "2021-2022"]["Title"].value_counts().reset_index()["Title"])

unique_2022 = list(banned_books_df[banned_books_df["Academic Year"] == "2022-2023"]["Title"].value_counts().reset_index()["Title"])

# %%
len([book for book in unique_2022 if book not in unique_2021])
# Out:
# 1257

# %%
# 1349 unique titles were banned in 2021 AY but not in 2022-2023
len([book for book in unique_2021 if book not in unique_2022])
# Out:
# 1349

# %%
# which books got unbanned (if that)?

maybe_unbanned = [book for book in unique_2021 if book not in unique_2022]

banned_books_df[(banned_books_df["Title"].isin(maybe_unbanned)) & 
                (banned_books_df["Academic Year"] == "2021-2022")]["Ban Status"].value_counts()
# Out:
# Ban Status
# Banned Pending Investigation          853
# Banned in Classrooms                  438
# Banned in Libraries                   178
# Banned in Libraries and Classrooms    117
# Name: count, dtype: int64

# %% [markdown]
# Most are under investigation so maybe they got returned to shelves. But unclear. The main point here is that accessibility to these books was censored for long periods

# %%
# getting data in the right format for visualization

# heirarchy of number of titles per ban status, per academic year 
banned_books_df.groupby(["Ban Status", "Academic Year"])["Title"].count().reset_index().sort_values("Academic Year")#.to_clipboard()
# Out:
#                               Ban Status Academic Year  Title
# 1           Banned Pending Investigation     2021-2022   1375
# 7                   Banned in Classrooms     2021-2022    487
# 8                    Banned in Libraries     2021-2022    337
# 9     Banned in Libraries and Classrooms     2021-2022    333
# 2           Banned Pending Investigation     2022-2023   1466
# 4                 Banned from Classrooms     2022-2023     29
# 5                  Banned from Libraries     2022-2023    603
# 6   Banned from Libraries and Classrooms     2022-2023   1263
# 0                                 Banned     2023-2024   4295
# 3                  Banned by restriction     2023-2024   1347
# 10          Banned pending investigation     2023-2024   4404

# %%
# checking to see if it grouped how I want it to
banned_books_df[banned_books_df["Academic Year"] == "2021-2022"]["Ban Status"].value_counts()
# Out:
# Ban Status
# Banned Pending Investigation          1375
# Banned in Classrooms                   487
# Banned in Libraries                    337
# Banned in Libraries and Classrooms     333
# Name: count, dtype: int64

# %%
# heirarchy of titles per ban status, per state, per academic year (think a sunburst chart)
banned_books_df.groupby(["Ban Status", "State", 
                         "Academic Year"])["Title"].count().reset_index().sort_values("Academic Year")
# Out:
#                        Ban Status      State Academic Year  Title
# 165           Banned in Libraries  Wisconsin     2021-2022     17
# 162           Banned in Libraries      Texas     2021-2022    163
# 163           Banned in Libraries       Utah     2021-2022      2
# 164           Banned in Libraries   Virginia     2021-2022      1
# 158           Banned in Libraries   Oklahoma     2021-2022      9
# ..                            ...        ...           ...    ...
# 67          Banned by restriction   Illinois     2023-2024      1
# 66          Banned by restriction      Idaho     2023-2024      1
# 65          Banned by restriction    Florida     2023-2024    988
# 73          Banned by restriction  Minnesota     2023-2024      1
# 203  Banned pending investigation  Wisconsin     2023-2024    238
#
# [204 rows x 4 columns]

# %% [markdown]
# # Focusing on 2023-2024

# %%
banned_books_df_2024 = banned_books_df[banned_books_df["Academic Year"] == "2023-2024"]

# %%
top5_states = banned_books_df_2024["State"].value_counts().head(5).reset_index()["State"].to_list()
top5_states
# Out:
# ['Florida', 'Iowa', 'Texas', 'Wisconsin', 'Virginia']

# %%
#filtering for top 10 states only

# %%
# heirarchy of titles per ban status, per state, per academic year (think a sunburst chart)
banned_books_df_2024[banned_books_df_2024["State"].isin(top5_states)].groupby(["Ban Status", "State"])["Title"].count().reset_index().sort_values("Title", ascending = False).to_clipboard()

# %% [markdown]
# ## Quick break to look at which states are not banning books

# %%
banned_books_df[banned_books_df["State"] == "California"]
# Out:
#             Author               Title                            Ban Status  \
# 3184  Dawson, Juno    This Book Is Gay  Banned from Libraries and Classrooms
# 8061  Dawson, Juno    This Book Is Gay                                Banned
# 9037   Green, John  Looking for Alaska                                Banned
#
#      Secondary Author(s) Illustrator(s) Translator(s)       State  \
# 3184                 NaN            NaN           NaN  California
# 8061                 NaN            NaN           NaN  California
# 9037                 NaN            NaN           NaN  California
#
#                                         District Date of Challenge/Removal  \
# 3184  William S. Hart Union High School District            September 2022
# 8061             Escondido Union School District              October 2023
# 9037             Escondido Union School District              October 2023
#
#      Origin of Challenge Academic Year
# 3184             Unclear     2022-2023
# 8061  Informal Challenge     2023-2024
# 9037      Administration     2023-2024

# %% [markdown]
# I am hesitant about drawing conclusions based on the map of states that haven't banned any books in the past 3 years (like Alabama or New Mexico). I don't think you can confidently say that somehow they care more about freedom of expression or are better about censorship -- maybe their initial educational offerings in libraries and classrooms were already stringent to begin with. We don't know

# %%
banned_books_df["State"].value_counts().reset_index().head(10) #Datawrapper chart made
# Out:
#             State  count
# 0         Florida   6533
# 1            Iowa   3685
# 2           Texas   1963
# 3    Pennsylvania    664
# 4       Wisconsin    480
# 5        Missouri    417
# 6       Tennessee    394
# 7            Utah    325
# 8        Virginia    215
# 9  South Carolina    192

# %% [markdown]
# ## Trying to make Radial Graphs

# %%
# getting the top 50 most banned authors for each academic year
df = banned_books_df.groupby(["Author","Academic Year"])["Title"].count().reset_index().sort_values(["Academic Year","Title"], 
                                                                                               ascending=False).groupby("Academic Year").head(50)

# %%
# save this csv
df.to_excel("top_banned_authors_perAY.xlsx", sheet_name="Banned Authors", index=False)

# %% [markdown]
# I did this to check if there were gender or identity trends in the authors being banned. I made a pictogram but I made it on Flourish and for the scope of this assigment, did not include it into the final piece. The pictogram shows the top author banned in each state, per academic year, categorized by their pronouns which serve as a nod to their gender identity. I manually encoded their pronouns by finding them on their instagram accounts, ALA articles about their books that include them, their own interviews or personal websites.

# %%
# top authors from each state for every academic year
banned_books_df.groupby(["Author", "State", "Academic Year"])["Title"].count().reset_index().sort_values(["State", "Title", "Academic Year"], ascending=False).groupby(["State","Academic Year"]).head(1).to_clipboard()

# %% [markdown]
# # Standardise Author Names

# %% [markdown]
# It's given as "last name, first name" in the dataset and was affecting readability in the visualization.

# %%
authors = pd.read_csv("data/top50_banned_2024.csv")
authors.head()

# %%
authors_list = authors["Author"].str.split(",").to_list()

# %%
authors["Author"] = [authors[1].strip()+ " " + authors[0].strip() for authors in authors_list]

# %%
authors.head()
# Out:
#           Author Academic Year  Title
# 0  Ellen Hopkins     2023-2024    523
# 1  Sarah J. Maas     2023-2024    481
# 2   Stephen King     2023-2024    173
# 3   Jodi Picoult     2023-2024    161
# 4     John Green     2023-2024    157

# %%
authors.to_csv("top50_banned_2024.csv", index = False)

# %% [markdown]
# # What are the top banned books each year?

# %% [markdown]
# From a reader's perspective - this is what they are most interested in. Atleast I would be

# %%
banned_books_df.groupby(["Title","Academic Year","Author"])["Ban Status"].count().reset_index().sort_values(["Academic Year","Ban Status"], ascending = [True,False]).groupby("Academic Year").head(10)
# Out:
#                                                 Title Academic Year  \
# 2196                           Gender Queer: A Memoir     2021-2022
# 374                              All Boys Aren't Blue     2021-2022
# 4035                                  Out of Darkness     2021-2022
# 5319                                   The Bluest Eye     2021-2022
# 3152                                         Lawn Boy     2021-2022
# 5782                                  The Hate U Give     2021-2022
# 5177  The Absolutely True Diary of a Part-Time Indian     2021-2022
# 3520                   Me and Earl and the Dying Girl     2021-2022
# 1389                             Crank (Crank Series)     2021-2022
# 5900                                  The Kite Runner     2021-2022
# 6826                                           Tricks     2022-2023
# 5320                                   The Bluest Eye     2022-2023
# 111                          A Court of Mist and Fury     2022-2023
# 3322                               Looking for Alaska     2022-2023
# 2197                           Gender Queer: A Memoir     2022-2023
# 6170                  The Perks of Being a Wallflower     2022-2023
# 4786                                             Sold     2022-2023
# 6685                             Thirteen Reasons Why     2022-2023
# 1387                                            Crank     2022-2023
# 1784                                 Empire of Storms     2022-2023
# 3845                                 Nineteen Minutes     2023-2024
# 3323                               Looking for Alaska     2023-2024
# 4787                                             Sold     2023-2024
# 6171                  The Perks of Being a Wallflower     2023-2024
# 1388                                            Crank     2023-2024
# 6686                             Thirteen Reasons Why     2023-2024
# 2765                                        Identical     2023-2024
# 5902                                  The Kite Runner     2023-2024
# 5775                              The Handmaid's Tale     2023-2024
# 6827                                           Tricks     2023-2024
#
#                    Author  Ban Status
# 2196         Kobabe, Maia          41
# 374    Johnson, George M.          29
# 4035   Pérez, Ashley Hope          23
# 5319       Morrison, Toni          22
# 3152     Evison, Jonathan          17
# 5782        Thomas, Angie          17
# 5177      Alexie, Sherman          16
# 3520       Andrews, Jesse          14
# 1389       Hopkins, Ellen          12
# 5900     Hosseini, Khaled          12
# 6826       Hopkins, Ellen          33
# 5320       Morrison, Toni          29
# 111        Maas, Sarah J.          27
# 3322          Green, John          27
# 2197         Kobabe, Maia          26
# 6170     Chbosky, Stephen          25
# 4786  McCormick, Patricia          24
# 6685           Asher, Jay          24
# 1387       Hopkins, Ellen          23
# 1784       Maas, Sarah J.          22
# 3845        Picoult, Jodi          98
# 3323          Green, John          97
# 4787  McCormick, Patricia          85
# 6171     Chbosky, Stephen          85
# 1388       Hopkins, Ellen          76
# 6686           Asher, Jay          76
# 2765       Hopkins, Ellen          74
# 5902     Hosseini, Khaled          73
# 5775     Atwood, Margaret          67
# 6827       Hopkins, Ellen          66

# %%
#sanity check for grouping
banned_books_df_2024["Title"].value_counts()
# Out:
# Title
# Nineteen Minutes                                     98
# Looking for Alaska                                   97
# The Perks of Being a Wallflower                      85
# Sold                                                 85
# Thirteen Reasons Why                                 76
#                                                      ..
# Shadow of the Hegemon                                 1
# Misery                                                1
# Mr. Mercedes                                          1
# Pastwatch: The Redemption of Christopher Columbus     1
# Next Summer                                           1
# Name: count, Length: 4240, dtype: int64
